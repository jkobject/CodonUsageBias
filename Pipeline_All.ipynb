# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pipeline1 as pi
import matplotlib.pyplot as plt

# %%
Genes = pi.Genes(doAll=True)
Genes.preprocess()

len(Genes.specieslist)
# Out:
# YDR397C
# YDR397C has non matching components for a same gene..
# YCL030C
# YCL030C has non matching components for a same gene..
# YDR280W
# YDR280W has non matching components for a same gene..
# YHL021C
# YHL021C has non matching components for a same gene..
# YBR216C
# YDR352W
# YDR352W has non matching components for a same gene..
# YGL163C
# YGL163C has non matching components for a same gene..
# YPL279C
# YPL279C has non matching components for a same gene..
# YER112W
# YER112W has non matching components for a same gene..
# YGR201C
# YGR201C has non matching components for a same gene..
# YHR014W
# YHR014W has non matching components for a same gene..
# YJL101C
# YJL101C has non matching components for a same gene..
# YIL042C
# YIL042C has non matching components for a same gene..
# YPL113C
# YPL113C has non matching components for a same gene..
# YGL019W
# YGL019W has non matching components for a same gene..
# YJL124C
# YJL124C has non matching components for a same gene..
# ...

# %%
Genes.genelist
# Out:
# ['kalfonDTA/YDR397C',
#  'kalfonDTA/YCL030C',
#  'kalfonDTA/YDR280W',
#  'kalfonDTA/YHL021C',
#  'kalfonDTA/YBR216C',
#  'kalfonDTA/YDR352W',
#  'kalfonDTA/YGL163C',
#  'kalfonDTA/YPL279C',
#  'kalfonDTA/YER112W',
#  'kalfonDTA/YGR201C',
#  'kalfonDTA/YHR014W',
#  'kalfonDTA/YJL101C',
#  'kalfonDTA/YIL042C',
#  'kalfonDTA/YPL113C',
#  'kalfonDTA/YGL019W',
#  'kalfonDTA/YJL124C',
#  'kalfonDTA/YML104C',
#  'kalfonDTA/YGR035C',
#  'kalfonDTA/YHR169W',
#  'kalfonDTA/YPL133C',
#  'kalfonDTA/YGR040W',
#  'kalfonDTA/YMR023C',
#  'kalfonDTA/YMR279C',
#  'kalfonDTA/YJL101C',
#  'kalfonDTA/YLR094C',
#  'kalfonDTA/YKR080W',
#  'kalfonDTA/YDR263C',
#  'kalfonDTA/YOR386W',
#  'kalfonDTA/YBR298C',
#  'kalfonDTA/YOR315W',
#  'kalfonDTA/YLR132C',
#  'kalfonDTA/YLR286C',
#  'kalfonDTA/YDR481C',
#  'kalfonDTA/YDR456W',
#  'kalfonDTA/YBR105C',
#  'kalfonDTA/YCL030C',
#  'kalfonDTA/YJL100W',
#  'kalfonDTA/YHL027W',
#  'kalfonDTA/YNL207W',
#  'kalfonDTA/YER029C',
#  'kalfonDTA/YGL067W',
# ...

# %% [markdown]
# ## T-sne reveals features :
#
# We can see that whatever is the input of tsne it seems that we have a blob of related gene through their bias.

# %%
colormap = ["#1abc9c","#3498db","#2ecc71","#9b59b6",'#34495e','#f1c40f','#e67e22','#e74c3c','#7f8c8d','#f39c12']

tsne = Genes.reduce_dim(gene, 2)
colors= [colormap[x] for x in labels]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(tsne[:,0],tsne[:,1], c = colors )
plt.show()

# %%
plt.scatter(tsne[:,0],tsne[:,1])

# %% [markdown]
# ## Interactive plot :

# %%
from bokeh.plotting import *
from bokeh.models import HoverTool
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="61115f09-17a3-45d7-9730-161942475629">Loading BokehJS ...</span>
#     </div>

# %%
GA = pi.Genes()
GA.plot_gene(tsne,Genes.specieslist[0],centroids=centroids,labels=labels)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="fdc92fb0-a241-4402-bbc9-3917787ca0d1"></div>
# </div>
# Figure(id='e80b7ff9-4850-459d-a4dc-9e6f558291d3', ...)
